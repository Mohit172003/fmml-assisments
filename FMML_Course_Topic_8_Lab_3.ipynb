# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohit172003/fmml-assisments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-06-15 05:24:24--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   212MB/s    in 0.3s
#
# 2023-06-15 05:24:29 (212 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11643  1608.06031v2  In the classical best arm identification (Best...    cs
# 1575   1802.00923v1  Human face-to-face communication is a complex ...    cs
# 5553    1207.4142v1  We consider the problem of modeling discrete-v...    cs
# 12592  1803.03666v1  We propose a Standing Wave Decomposition (SWD)...  stat
# 21590   1106.0762v1  This paper addresses the problem of inferring ...  stat
# ...             ...                                                ...   ...
# 22106   1411.6203v1  Several problems such as network intrusion, co...  stat
# 27846  1704.07056v2  Since the matrix formed by nonlocal similar pa...    cs
# 30399  1712.01381v2  Most existing zero-shot learning methods consi...    cs
# 30874  1801.07388v1  In recent years, deep neural network approache...    cs
# 31240  1802.07934v1  We propose a method for semi-supervised semant...    cs
#
#                                                    title  year  \
# 11643  Towards Instance Optimal Bounds for Best Arm I...  2016
# 1575   Multi-attention Recurrent Network for Human Co...  2018
# 5553   Conditional Chow-Liu Tree Structures for Model...  2012
# 12592       Standing Wave Decomposition Gaussian Process  2018
# 21590  Causal Network Inference via Group Sparse Regu...  2011
# ...                                                  ...   ...
# 22106       Efficient Minimax Signal Detection on Graphs  2014
# 27846  Non-Convex Weighted Lp Nuclear Norm based ADMM...  2017
# 30399  Imagine it for me: Generative Adversarial Appr...  2017
# 30874     Let's Dance: Learning From Online Dance Videos  2018
# 31240  Adversarial Learning for Semi-Supervised Seman...  2018
#
#                                                 keywords
# 11643  [classical, identification, stochastic, associ...
# 1575   [communication, multimodal, intentions, unders...
# 5553   [extensions, dependencies, dependencies, varia...
# 12592  [decomposition, approximation, regression, inv...
# 21590  [addresses, inferring, multivariate, regressiv...
# ...                                                  ...
# 22106  [intrusion, community, detection, described, o...
# 27846  [minimization, processing, nonetheless, surrog...
# 30399  [embedding, demonstrated, capability, generati...
# 30874  [approaches, naturally, aggregating, classific...
# 31240  [supervised, segmentation, adversarial, discri...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11643    [classical, identification, stochastic, associ...
# 1575     [communication, multimodal, intentions, unders...
# 5553     [extensions, dependencies, dependencies, varia...
# 12592    [decomposition, approximation, regression, inv...
# 21590    [addresses, inferring, multivariate, regressiv...
#                                ...
# 21515    [arbitrary, dependencies, distribution, afterw...
# 143      [prediction, challenging, prediction, continua...
# 27493    [algorithm, optimization, framework, conjuncti...
# 35077    [distributed, algorithms, implemented, simplif...
# 22537    [discovering, relationships, compression, info...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 9085 words.
# Out of those 4605 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cec4e2e5-599a-4b32-871b-90da272d1bdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cec4e2e5-599a-4b32-871b-90da272d1bdf")) {                    Plotly.newPlot(                        "cec4e2e5-599a-4b32-871b-90da272d1bdf",                        [{"x":["corresponding","attention","determined","significant","associated","concerning","attracted","conjecture","probability","distribution","expectation","identification","nontrivial","understanding","complexity","classical","resolution","stochastic","algorithm","recognition","interactions","extensive","sentiment","available","intentions","modalities","comparisons","performance","architecture","comprehension","communication","intelligence","artificial","discovering","challenge","understand","component","recurrent","multimodal","effectiveness","interpretation","variables","representations","distributions","parsimonious","simulating","extension","parameters","illustrate","structures","dependencies","structure","forecasting","important","precipitation","alternatives","extensions","densities","historical","occurrence","algorithms","conditional","introduced","australia","demonstrate","meteorological","diagonalization","regression","approximate","applicability","correlations","simulations","plentiful","approximation","approximated","relatively","predictive","recommended","operation","constraints","outperforms","dimensional","computation","inversion","decomposition","computational","consistent","regressive","estimates","procedure","observations","particular","regularization","inferring","multivariate","reversing","direction","asymptotic","conditions","inference","influence","addresses","consistently","processes","simulation","experiments","describing","condition","demonstrated","connection","constructing","retrieval","explicitly","panoramic","individual","aggregating","benchmark","introduces","extremely","throughout","generalize","generative","restoration","colorization","thoroughly","processed","developments","automatic","contained","attempted","application","information","convolutional","assignment","tradition","adversarial","grayscale","different","qualitative","annotation","expensive","framework","visualizations","applications","quantities","consuming","supervised","improving","beneficial","discriminative","combination","principled","unlabeled","capitalize","improvements","objective","laborious","manifolds","implemented","implementation","differential","introduce","similarly","calculation","automated","potential","differentiation","differentiable","geometries","optimization","described","implements","derivatives","calculating","experimenting","derivative","constraint","separation","projection","nonnegative","recursive","factorization","separable","advantage","nonnegativity","hyperspectral","successive","synthetic","illustrated","sufficiently","constitutes","assumptions","efficient","magnitude","dependence","theoretic","fundamental","necessary","specifically","knowledge"],"y":[126,140,43,242,116,13,22,6,184,198,42,107,6,169,238,100,108,129,808,376,64,189,42,333,10,44,29,884,228,14,55,95,135,30,151,66,104,137,38,232,62,120,241,124,3,10,95,229,83,111,44,348,20,328,2,35,37,11,23,30,588,114,148,4,587,6,0,105,98,35,23,36,0,117,17,57,57,1,45,134,284,163,143,13,60,294,84,1,75,126,60,282,82,16,24,1,66,13,120,233,61,57,37,96,83,636,33,35,80,46,57,108,82,3,126,15,208,87,54,25,52,109,13,7,15,32,26,174,22,7,233,712,353,33,4,101,8,772,57,67,59,566,11,432,17,31,182,110,23,94,140,34,40,3,107,170,7,21,101,144,28,300,19,20,103,172,5,19,4,313,83,8,14,19,6,8,83,17,55,12,25,40,12,79,2,15,16,137,17,13,10,69,405,61,30,52,72,73,172,363],"type":"bar"},{"x":["corresponding","attention","determined","significant","ass ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4605,), (4605, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8033333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Skopus</span> <span style=''>Mining</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>patterns</span> <span style=''>under</span> <span style=''>leverage</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>of</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>patterns</span> <span style=''>under</span> <span style=''>Leverage</span> <span style=''>It</span> <span style=''>combines</span> <span style=''>(1)</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.37142857142857144);'>definition</span> <span style=''>of</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>support</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>pattern</span> <span style=''>a</span> <span style=''>concept</span> <span style=''>on</span> <span style=''>which</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interestingness</span> <span style=''>measures</span> <span style=''>directly</span> <span style=''>rely</span> <span style=''>with</span> <span style=''>(2)</span> <span style=''>SkOPUS</span> <span style=''>a</span> <span style=''>new</span> <span style=''>branch</span> <span style=''>and</span> <span style=''>bound</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discovery</span> <span style=''>of</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style=''>patterns</span> <span style=''>under</span> <span style=''>a</span> <span style=''>given</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interestingness</span> <span style=''>measure</span> <span style=''>employs</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>approach</span> <span style=''>A</span> <span style=''>pattern</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style=''>to</span> <span style=''>the</span> <span style=''>extent</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>more</span> <span style=''>frequent</span> <span style=''>than</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explained</span> <span style=''>by</span> <span style=''>assuming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independence</span> <span style=''>between</span> <span style=''>any</span> <span style=''>of</span> <span style=''>the</span> <span style=''>pairs</span> <span style=''>of</span> <span style=''>patterns</span> <span style=''>from</span> <span style=''>which</span> <span style=''>it</span> <span style=''>can</span> <span style=''>be</span> <span style=''>composed</span> <span style=''>The</span> <span style=''>larger</span> <span style=''>the</span> <span style=''>support</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectation</span> <span style=''>under</span> <span style='bac ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>IT</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dendrogram</span> <span style=''>A</span> <span style=''>New</span> <span style=''>Member</span> <span style=''>of</span> <span style=''>the</span> <span style=''>In</span> <span style=''>Tree</span> <span style=''>(IT)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>Family</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Previously</span> <span style=''>we</span> <span style=''>proposed</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physically</span> <span style=''>inspired</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>data</span> <span style=''>points</span> <span style=''>into</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>in</span> <span style=''>tree</span> <span style=''>(IT)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>cluster</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>is</span> <span style=''>well</span> <span style=''>revealed</span> <span style=''>Although</span> <span style=''>there</span> <span style=''>are</span> <span style=''>some</span> <span style=''>edges</span> <span style=''>in</span> <span style=''>the</span> <span style=''>IT</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>to</span> <span style=''>be</span> <span style=''>removed</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undesired</span> <span style=''>edges</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinguishable</span> <span style=''>from</span> <span style=''>other</span> <span style=''>edges</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>are</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>For</span> <span style=''>instance</span> <span style=''>when</span> <span style=''>the</span> <span style=''>IT</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>for</span> <span style=''>the</span> <span style=''>2</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>(2D)</span> <span style=''>datasets</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>graphically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>those</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>undesired</span> <span style=''>edges</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>spotted</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>However</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>there</span> <span style=''>are</span> <span style=''>many</span> <span style=''>datasets</span> <span style=''>that</span> <span style=''>do</span> <span style=''>not</span> <span style=''>lie</span> <span style=''>in</span> <span style=''>the</span> <span style=''>2D</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclid ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538475);'>Factorization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partition</span> <span style=''>of</span> <span style=''>Complex</span> <span style=''>Networks</span> <span style=''>From</span> <span style=''>Random</span> <span style=''>Walks</span> <br/><br/><span style=''>Finding</span> <span style=''>the</span> <span style=''>reduced</span> <span style='background-color:rgba(255, 0, 0, 0.39741219963031427);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3151750972762646);'>understanding</span> <span style=''>complex</span> <span style=''>networks</span> <span style=''>Existing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>such</span> <span style=''>as</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>only</span> <span style=''>when</span> <span style=''>the</span> <span style=''>full</span> <span style=''>network</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>observed</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>the</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538475);'>factorization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partition</span> <span style=''>of</span> <span style=''>implicit</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>networks</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.4312796208530805);'>observations</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>random</span> <span style=''>walk</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>this</span> <span style=''>into</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.46666666666666673);'>nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3737864077669902);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538475);'>factorization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.3737864077669902);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalized</span> <span style=''>Hebbian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.5217391304347827);'>dynamically</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>network</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Random</span> <span style=''>Fourier</span> <span style=''>Features</span> <span style=''>by</span> <span style=''>Hybrid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>The</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>for</span> <span style=''>adapting</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>Since</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>consumes</span> <span style=''>a</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>cost</span> <span style=''>in</span> <span style=''>the</span> <span style=''>testing</span> <span style=''>phase</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>teacher</span> <span style=''>learner</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>from</span> <span style=''>specific</span> <span style=''>data</span> <span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>the</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>(teacher)</span> <span style=''>transfer</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>(learner)</span> <span style=''>We</span> <span style=''>jointly</span> <span style=''>select</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>informative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>and</span> <span style=''>pursue</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>between</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>approach</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximization</span> <span style=''>(CVEM)</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08145766345123258)
# 	challenging (0.09753483386923902)
# 	knowledge (0.12968917470525188)
# 	experimental (0.13897820650232226)
# 	segmentation (0.07324044301536263)
# 	information (0.2543765630582351)
# 	detection (0.1279028224365845)
# 	convolutional (0.1261164701679171)
# 	recognition (0.13433369060378705)
# 	different (0.27581279028224365)
#
# Some Statistics words are:
# 	stochastic (0.14142928535732133)
# 	variables (0.13943028485757122)
# 	algorithm (0.3893053473263368)
# 	theoretical (0.15642178910544727)
# 	estimation (0.1774112943528236)
# 	statistical (0.16491754122938532)
# 	inference (0.20339830084957522)
# 	distribution (0.191904047976012)
# 	dimensional (0.1889055472263868)
# 	regression (0.19640179910044978)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3ec4e5ba-1c9b-417e-806c-a6b835097cea" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ec4e5ba-1c9b-417e-806c-a6b835097cea")) {                    Plotly.newPlot(                        "3ec4e5ba-1c9b-417e-806c-a6b835097cea",                        [{"x":["corresponding","attention","determined","significant","associated","concerning","attracted","conjecture","probability","distribution","expectation","identification","nontrivial","understanding","complexity","classical","resolution","stochastic","algorithm","recognition","interactions","extensive","sentiment","available","intentions","modalities","comparisons","performance","architecture","comprehension","communication","intelligence","artificial","discovering","challenge","understand","component","recurrent","multimodal","effectiveness","interpretation","variables","representations","distributions","parsimonious","simulating","extension","parameters","illustrate","structures","dependencies","structure","forecasting","important","precipitation","alternatives","extensions","densities","historical","occurrence","algorithms","conditional","introduced","australia","demonstrate","meteorological","diagonalization","regression","approximate","applicability","correlations","simulations","plentiful","approximation","approximated","relatively","predictive","recommended","operation","constraints","outperforms","dimensional","computation","inversion","decomposition","computational","consistent","regressive","estimates","procedure","observations","particular","regularization","inferring","multivariate","reversing","direction","asymptotic","conditions","inference","influence","addresses","consistently","processes","simulation","experiments","describing","condition","demonstrated","connection","constructing","retrieval","explicitly","panoramic","individual","aggregating","benchmark","introduces","extremely","throughout","generalize","generative","restoration","colorization","thoroughly","processed","developments","automatic","contained","attempted","application","information","convolutional","assignment","tradition","adversarial","grayscale","different","qualitative","annotation","expensive","framework","visualizations","applications","quantities","consuming","supervised","improving","beneficial","discriminative","combination","principled","unlabeled","capitalize","improvements","objective","laborious","manifolds","implemented","implementation","differential","introduce","similarly","calculation","automated","potential","differentiation","differentiable","geometries","optimization","described","implements","derivatives","calculating","experimenting","derivative","constraint","separation","projection","nonnegative","recursive","factorization","separable","advantage","nonnegativity","hyperspectral","successive","synthetic","illustrated","sufficiently","constitutes","assumptions","efficient","magnitude","dependence","theoretic","fundamental","necessary","specifically","knowledge","quadratic","alternating","processing","structured","simplicity","demonstrates","recovering","measurements","additional","minimization","convergence","coefficients","compressive","additionally","formulating","assistance","occlusion","canonical","approaches","experimental","contributions","explanation","reasoning","identifying","exploiting","variations","combinatorial","leveraging","successfully","heuristic","correspondences","perception","tractable","hypothesized","localization","deliberative","parallelization","localizing","manufacturing","unreliable","descriptors","generation","assessment","effectively","automatically","interpretability","prediction","aesthetic","components","annotations","interpretable","leveraged","proper ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	diagonalization
# 	plentiful
# 	advocated
# 	infectious
# 	modulating
# 	heteroskedastic
# 	delivering
# 	spectrometry
# 	microbial
# 	bivariate
# 	morgenstern
# 	chemometrics
# 	newsgroup
# 	delineates
# 	censoring
# 	orthogonality
# 	economists
# 	collapsed
# 	detectability
# 	amortised
# Some words which never appear in Statistics papers:
# 	intentions
# 	precipitation
# 	colorization
# 	grayscale
# 	deliberative
# 	localizing
# 	photography
# 	watershed
# 	lexicographic
# 	skeletons
# 	rationality
# 	reconsiders
# 	disparity
# 	crossover
# 	handcrafted
# 	inevitably
# 	misalignment
# 	wearables
# 	incomparable
# 	declarative

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.067955207853966e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
